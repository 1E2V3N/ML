# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
from matplotlib.ticker import PercentFormatter
import sklearn

# %%
data = pd.read_excel("C:/Users/user/Downloads/Data Science Case Study/Case 1 - Winemakers.xlsx")

# %%
data = data["style"].value_counts(normalize=True)
data.plot(kind='bar',figsize=(15,6))
plt.title("Wine class proportion",fontsize= 16)
plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
plt.show()

# %%
data.describe()
# Out:
# count    2.000000
# mean     0.500000
# std      0.359050
# min      0.246114
# 25%      0.373057
# 50%      0.500000
# 75%      0.626943
# max      0.753886
# Name: proportion, dtype: float64

# %%
data
# Out:
# style
# white    0.753886
# red      0.246114
# Name: proportion, dtype: float64

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
data_1=data[(data['quality']==8) | (data['quality']==9)].reset_index().drop(['index'],axis=1)
data_1
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides
# 0              7.9             0.350         0.46             3.6      0.078  \
# 1             10.3             0.320         0.45             6.4      0.073
# 2              5.6             0.850         0.05             1.4      0.045
# 3             12.6             0.310         0.72             2.2      0.072
# 4             11.3             0.620         0.67             5.2      0.086
# ..             ...               ...          ...             ...        ...
# 193            5.2             0.300         0.34             1.5      0.038
# 194            6.4             0.320         0.25             5.0      0.055
# 195            4.4             0.320         0.39             4.3      0.030
# 196            3.9             0.225         0.40             4.2      0.030
# 197            5.8             0.280         0.34             2.2      0.037
#
#      free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates
# 0                   15.0                  37.0  0.99730  3.35       0.86  \
# 1                    5.0                  13.0  0.99760  3.23       0.82
# 2                   12.0                  88.0  0.99240  3.56       0.82
# 3                    6.0                  29.0  0.99870  2.88       0.82
# 4                    6.0                  19.0  0.99880  3.22       0.69
# ..                   ...                   ...      ...   ...        ...
# 193                 18.0                  96.0  0.98942  3.56       0.48
# 194                 28.0                 138.0  0.99171  3.27       0.50
# 195                 31.0                 127.0  0.98904  3.46       0.36
# 196                 29.0                 118.0  0.98900  3.57       0.36
# 197                 24.0                 125.0  0.98986  3.36       0.33
#
#      alcohol  quality  style
# 0       12.8        8    red
# 1       12.6        8    red
# 2       12.9        8    red
# 3        9.8        8    red
# 4       13.4        8    red
# ..       ...      ...    ...
# 193     13.0        8  white
# 194     12.4        8  white
# 195     12.8        8  white
# 196     12.8        8  white
# 197     12.8        8  white
#
# [198 rows x 13 columns]

# %%
# ## EDA - Correlation Graph( Heat Map ) of the entire data.

# ## Analysis - 1

# %%
data.drop(['style'],axis=1).corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_f9549_row0_col0, #T_f9549_row1_col1, #T_f9549_row2_col2, #T_f9549_row3_col3, #T_f9549_row4_col4, #T_f9549_row5_col5, #T_f9549_row6_col6, #T_f9549_row7_col7, #T_f9549_row8_col8, #T_f9549_row9_col9, #T_f9549_row10_col10, #T_f9549_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f9549_row0_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f9549_row0_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f9549_row0_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f9549_row0_col4, #T_f9549_row0_col9, #T_f9549_row9_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f9549_row0_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f9549_row0_col6, #T_f9549_row11_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f9549_row0_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f9549_row0_col8, #T_f9549_row8_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f9549_row0_col10 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f9549_row0_col11, #T_f9549_row10_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_f9549_row1_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_f9549_row1_col2, #T_f9549_row1_col5, #T_f9549_row1_col6, #T_f9549_row2_col8, #T_f9549_row6_col0, #T_f9549_row6_col1, #T_f9549_row6_col4, #T_f9549_row6_col9, #T_f9549_row7_col10, #T_f9549_row7_col11, #T_f9549_row10_col3, #T_f9549_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f9549_row1_col3, #T_f9549_row3_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f9549_row1_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f9549_row1_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f9549_row1_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f9549_row1_col9, #T_f9549_row9_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f9549_row1_col10 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_f9549_row1_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f9549_row2_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f9549_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f9549_row2_col3, #T_f9549_row5_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_f9549_row2_col4, #T_f9549_row6_col10, #T_f9549_row8_col11, #T_f9549_row11_col9 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f9549_row2_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f9549_row2_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_f9549_row2_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f9549_row2_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f9549_row2_col10 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f9549_row2_col11, #T_f9549_row5_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f9549_row3_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f9549_row3_col1, #T_f9549_row8_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f9549_row3_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_f9549_row3_col5 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f9549_row3_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f9549_row3_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_f9549_row3_col8 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f9549_row3_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f9549_row3_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f9549_row3_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f9549_row4_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f9549_row4_col1, #T_f9549_row5_col3, #T_f9549_row9_col7 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f9549_row4_col2, #T_f9549_row11_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f9549_row4_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_f9549_row4_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f9549_row4_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f9549_row4_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f9549_row4_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f9549_row4_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f9549_row4_col10, #T_f9549_row7_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_f9549_row4_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col0, #T_f9549_row8_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col6 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_f9549_row5_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col9, #T_f9549_row6_col8, #T_f9549_row8_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f9549_row5_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_f9549_row6_col2, #T_f9549_row8_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f9549_row6_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_f9549_row6_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_f9549_row6_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f9549_row6_col11 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f9549_row7_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_f9549_row7_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f9549_row7_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f9549_row7_col3, #T_f9549_row11_col10 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_f9549_row7_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_f9549_row7_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f9549_row7_col6, #T_f9549_row9_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f9549_row7_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f9549_row8_col1, #T_f9549_row8_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f9549_row8_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f9549_row8_col6, #T_f9549_row9_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f9549_row8_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_f9549_row9_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f9549_row9_col3, #T_f9549_row10_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f9549_row9_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f9549_row9_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f9549_row9_col10 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f9549_row9_col11, #T_f9549_row11_col6, #T_f9549_row11_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f9549_row10_col1, #T_f9549_row10_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f9549_row10_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f9549_row10_col6, #T_f9549_row11_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f9549_row10_col8, #T_f9549_row11_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f9549_row10_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f9549_row10_col11 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f9549_row11_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f9549_row11_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f9549_row11_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9549">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9549_level0_col0" class="col_heading level0 col0" >fixed_acidity</th>
#       <th id="T_f9549_level0_col1" class="col_heading level0 col1" >volatile_acidity</th>
#       <th id="T_f9549_level0_col2" class="col_heading level0 col2" >citric_acid</th>
#       <th id="T_f9549_level0_col3" class="col_heading level0 col3" >residual_sugar</th>
#       <th id="T_f9549_level0_col4" class="col_heading l

# %%
# ## Insights:
# 
# By this we can understand that the "quality" is positively correlated with citric acid, free_sulfur_dioxide,
# pH, sulphate and alcohol.
# 
# In case of feature selection we can consider those variables having positive effect on the quality of wine i.e if these parametres are increased, the wine quality will increase

# ### To validate the correlation results we would try to compare the average of independent variable accross all quality.

# %%
# ## Analysis - 2

# %%
data_F = data.drop(['style'],axis=1)

# %%
data_F['quality'] = data_F['quality'].astype(float)

# %%
val = data_F.groupby(['quality']).mean()
val
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# quality
# 3.0           7.853333          0.517000     0.281000        5.140000  \
# 4.0           7.288889          0.457963     0.272315        4.153704
# 5.0           7.326801          0.389614     0.307722        5.804116
# 6.0           7.177257          0.313863     0.323583        5.549753
# 7.0           7.128962          0.288800     0.334764        4.731696
# 8.0           6.835233          0.291010     0.332539        5.382902
# 9.0           7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density
# quality
# 3.0       0.077033            39.216667            122.033333  0.995744  \
# 4.0       0.060056            20.636574            103.432870  0.994833
# 5.0       0.064666            30.237371            120.839102  0.995849
# 6.0       0.054157            31.165021            115.410790  0.994558
# 7.0       0.045272            30.422150            108.498610  0.993126
# 8.0       0.041124            34.533679            117.518135  0.992514
# 9.0       0.027400            33.400000            116.000000  0.991460
#
#                pH  sulphates    alcohol
# quality
# 3.0      3.257667   0.506333  10.215000
# 4.0      3.231620   0.505648  10.180093
# 5.0      3.212189   0.526403   9.837783
# 6.0      3.217726   0.532549  10.587553
# 7.0      3.228072   0.547025  11.386006
# 8.0      3.223212   0.512487  11.678756
# 9.0      3.308000   0.466000  12.180000

# %%
# ## Insights:
# 
# The mean value of citric_acid is high for the high quality wine and reduces as the quality reduces.
# 
# The mean value of sulphate level reduces as the Quality of wine increase.
# 
# We can see the mean value of sulphate is always high is case of red wine compare to white wine. We can suggest to reduce the sulphate level to better the quality of the wines. This will reduce the acidity and intensity color of red wine which inturn improves the wine quality.
# 
# Lastly, higher the alcohol level better the wine.

# %%
# ## Analysis - 3
# 
# WHITE WINE

# %%
data['style'].replace(['red', 'white'],
                        [0, 1], inplace=True)

# %%
val_red = data[data['style']==1].groupby(['quality']).mean()
val_red
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# quality
# 3             7.600000          0.333250     0.336000        6.392500  \
# 4             7.129448          0.381227     0.304233        4.628221
# 5             6.933974          0.302011     0.337653        7.334969
# 6             6.837671          0.260564     0.338025        6.441606
# 7             6.734716          0.262767     0.325625        5.186477
# 8             6.657143          0.277400     0.326514        5.671429
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density
# quality
# 3         0.054300            53.325000            170.600000  0.994884  \
# 4         0.050098            23.358896            125.279141  0.994277
# 5         0.051546            36.432052            150.904598  0.995263
# 6         0.045217            35.650591            137.047316  0.993961
# 7         0.038191            34.125568            125.114773  0.992452
# 8         0.038314            36.720000            126.165714  0.992236
# 9         0.027400            33.400000            116.000000  0.991460
#
#                pH  sulphates    alcohol  style
# quality
# 3        3.187500   0.474500  10.345000    1.0
# 4        3.182883   0.476135  10.152454    1.0
# 5        3.168833   0.482203   9.808840    1.0
# 6        3.188599   0.491106  10.575372    1.0
# 7        3.213898   0.503102  11.367936    1.0
# 8        3.218686   0.486229  11.636000    1.0
# 9        3.308000   0.466000  12.180000    1.0

# %%
df = data[data['style']==1]
df.iloc[:,:-1].corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_afa95_row0_col0, #T_afa95_row1_col1, #T_afa95_row2_col2, #T_afa95_row3_col3, #T_afa95_row4_col4, #T_afa95_row5_col5, #T_afa95_row6_col6, #T_afa95_row7_col7, #T_afa95_row8_col8, #T_afa95_row9_col9, #T_afa95_row10_col10, #T_afa95_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_afa95_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_afa95_row0_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_afa95_row0_col3, #T_afa95_row0_col6, #T_afa95_row1_col6, #T_afa95_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_afa95_row0_col4, #T_afa95_row1_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_afa95_row0_col5, #T_afa95_row3_col8, #T_afa95_row3_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_afa95_row0_col7, #T_afa95_row3_col6, #T_afa95_row6_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_afa95_row0_col8, #T_afa95_row1_col9, #T_afa95_row7_col10, #T_afa95_row7_col11, #T_afa95_row8_col0, #T_afa95_row8_col2, #T_afa95_row10_col3, #T_afa95_row10_col4, #T_afa95_row10_col5, #T_afa95_row10_col6, #T_afa95_row10_col7, #T_afa95_row11_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_afa95_row0_col9, #T_afa95_row10_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_afa95_row0_col10, #T_afa95_row11_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_afa95_row0_col11 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_afa95_row1_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_afa95_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_afa95_row1_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_afa95_row1_col5 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_afa95_row1_col7, #T_afa95_row7_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_afa95_row1_col8, #T_afa95_row2_col5, #T_afa95_row9_col4, #T_afa95_row9_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_afa95_row1_col10 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_afa95_row1_col11, #T_afa95_row11_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_afa95_row2_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_afa95_row2_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_afa95_row2_col3 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_afa95_row2_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_afa95_row2_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_afa95_row2_col7 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_afa95_row2_col8, #T_afa95_row3_col10, #T_afa95_row6_col10, #T_afa95_row7_col1, #T_afa95_row8_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_afa95_row2_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_afa95_row2_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_afa95_row2_col11 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_afa95_row3_col0, #T_afa95_row6_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_afa95_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_afa95_row3_col2, #T_afa95_row4_col1, #T_afa95_row5_col2, #T_afa95_row10_col1, #T_afa95_row11_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_afa95_row3_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_afa95_row3_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_afa95_row3_col7 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_afa95_row3_col9 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_afa95_row4_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_afa95_row4_col2, #T_afa95_row5_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_afa95_row4_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_afa95_row4_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_afa95_row4_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_afa95_row4_col8, #T_afa95_row4_col10, #T_afa95_row6_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_afa95_row4_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_afa95_row4_col11, #T_afa95_row10_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_afa95_row5_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_afa95_row5_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_afa95_row5_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_afa95_row5_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_afa95_row5_col6, #T_afa95_row6_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_afa95_row5_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_afa95_row5_col8, #T_afa95_row5_col10, #T_afa95_row6_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_afa95_row5_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_afa95_row6_col2, #T_afa95_row11_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_afa95_row6_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_afa95_row6_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_afa95_row6_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_afa95_row6_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_afa95_row7_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_afa95_row7_col2, #T_afa95_row11_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_afa95_row7_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_afa95_row7_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_afa95_row7_col6 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_afa95_row7_col8 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_afa95_row7_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_afa95_row8_col1, #T_afa95_row9_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_afa95_row8_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_afa95_row8_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_afa95_row8_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_afa95_row8_col6, #T_afa95_row8_col11 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_afa95_row8_col7, #T_afa95_row10_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_afa95_row8_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_afa95_row9_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_afa95_row9_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_afa95_row9_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_afa95_row9_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_afa95_row9_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_afa95_row9_col7 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_afa95_row9_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_afa95_row9_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_afa95_row10_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_afa95_row10_col11 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_afa95_row11_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_afa95_row11_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_afa95_row11_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_afa95_row11_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_afa95_row11_col10 {
#   background-color: #f7b396;
#   color: #000000;
# }
# </style>
# <table id="T_afa95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afa95_level0_col0" class="col_heading level0 col0" >fixed_acidity</th>
#       <th id="T_afa95_level0_col1" class="col_heading level0 col1" >volatile_acidity</th>
#       <th id="T_afa95_level0_col2" class="col_heading level0 col2" >citric_acid</th>
#       <th id="T_afa95_level0_col3" class="col_heading level0 col3" >residual_sugar</th>
#       <th id="T_afa95_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_afa95_level0_col5" class="col_heading level0 col5" >free_sulfur_dioxide</th>
#       <th id="T_afa95_level0_col6" class="col_heading level0 col6" >total_sulfur_dioxide</th>
#       <th id="T_afa95_level0_col7"

# %%
# ## Insights:
# 
# The mean value of pH is high for high qulity wine, meaning the high quality wine's taste softer and the has pleasant
# smell.
# 
# The residual_sugar level decreases as quality increase. The low quality wine are sweeter in general. 
# 
# 
# 
# ### Suggestion to White wine makers: As compared to Red wine, White wine needs to have a softer taste to be good quality. By increasing the ph and decreasing the suger we can improve the quality of the white wine.

# %%
# ## Analysis - 5 Oulier Detection
# 
# Using seaborn function we have plotted the graph of all the numerical independent 
#variables to understand the distribution and outlier present in the data.
# 
# By these graphs we understand that a few variables are right skewed and have extreme outlier 
#the we would try to resolve this by doing an outlier treatement.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [6, 2]

columns = data.columns.tolist()
columns.remove('style')

for column in columns:
    plt.figure()
    sns.distplot(data[column])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\1485448741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column])

# %%
out_values=data.iloc[:,:-1].describe(percentiles=[0.05,0.95])
out_values.drop(['count', 'mean', 'std', 'min', '50%', 'max'], axis=0, inplace=True)

# %%
df = data.iloc[:,:-1]

# %%
for i in out_values.columns:
    check= (lambda x: x if x>=out_values.loc['5%',i] and x<=out_values.loc['95%',i] else df[i].mean() )
    df[i]= df[i].apply(check)

# %%
plt.rcParams['figure.figsize'] = [6, 2]

columns = df.columns.tolist()


for column in columns:
    plt.figure()
    sns.distplot(df[column])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# C:\Users\user\AppData\Local\Temp\ipykernel_27464\3507853723.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 8
#       6 for column in columns:
#       7     plt.figure()
# ----> 8     sns.distplot(df[column])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:2511, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2509 if kde:
#    2510     kde_color = kde_kws.pop("color", color)
# -> 2511     kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
#    2512     if kde_color != color:
#    2513         kde_kws["color"] = kde_color
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1717, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1713 if p.univariate:
#    1715     plot_kws = kwargs.copy()
# -> 1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    1720         common_grid=common_grid,
#    1721         fill=fill,
#    1722         color=color,
#    1723         legend=legend,
#    1724         warn_singular=warn_singular,
#    1725         estimate_kws=estimate_kws,
#    1726         **plot_kws,
#    1727     )
#    1729 else:
#    1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    (...)
#    1743         **kwargs,
#    1744     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:937, in _DistributionPlotter.plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, color, legend, estimate_kws, **plot_kws)
#     934 log_scale = self._log_scaled(self.data_variable)
#     936 # Do the computation
# --> 937 densities = self._compute_univariate_density(
#     938     self.data_variable,
#     939     common_norm,
#     940     common_grid,
#     941     estimate_kws,
#     942     log_scale,
#     943     warn_singular,
#     944 )
#     946 # Adjust densities based on the `multiple` rule
#     947 densities, baselines = self._resolve_multiple(densities, multiple)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:349, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     345 try:
#     346     if not singular:
#     347         # Convoluted approach needed because numerical failures
#     348         # can manifest in a few different ways.
# --> 349         density, support = estimator(observations, weights=weights)
#     350 except np.linalg.LinAlgError:
#     351     singular = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_statistics.py:192, in KDE.__call__(self, x1, x2, weights)
#     190 """Fit and evaluate on univariate or bivariate data."""
#     191 if x2 is None:
# --> 192     return self._eval_univariate(x1, weights)
#     193 else:
#     194     return self._eval_bivariate(x1, x2, weights)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_statistics.py:161, in KDE._eval_univariate(self, x, weights)
#     157     density = np.array([
#     158         kde.integrate_box_1d(s_0, s_i) for s_i in support
#     159     ])
#     160 else:
# --> 161     density = kde(support)
#     163 return density, support
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_kde.py:268, in gaussian_kde.evaluate(self, points)
#     265         raise ValueError(msg)
#     267 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 268 result = gaussian_kernel_estimate[spec](
#     269     self.dataset.T, self.weights[:, None],
#     270     points.T, self.cho_cov, output_dtype)
#     272 return result[:, 0]
#
# KeyboardInterrupt:

# %%
# ## Data Preparation - Train test Split
# 
# ### We have used correlation to select the independent variable for the modelling purpose.
#

# %%
# regression

# x= df.loc[:,['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#              'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol']]

x=df.loc[:,['fixed_acidity', 'volatile_acidity','residual_sugar',
       'chlorides', 'total_sulfur_dioxide',
       'pH', 'sulphates', 'alcohol']]

# x=df.loc[:,["volatile_acidity","citric_acid","chlorides","density","sulphates"]]
y= df.loc[:,'quality']

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.score(xtest,ytest)
# Out:
# 0.19114573034357074

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: 2.6696780521584

# %%
y = 0* 20 + 2.5* 10 + c

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [-2.72298866e-02 -7.56123956e-01  8.99338258e-03 -4.53898112e+00
#  -1.01786527e-03  2.96926837e-01  6.54397174e-01  2.49314763e-01]

# %%
# #### Model - Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import RepeatedKFold


cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Ridge
from numpy import absolute
from numpy import std
from numpy import mean

# %%
model = Ridge(alpha=1.0)

cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

scores = cross_val_score(model, xtrain,ytrain, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %%
cores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Mean MAE: -0.503 (0.016)

# %%
# #### Model - Decision tree regression

# %%
#decision tree regression

from sklearn.tree import DecisionTreeRegressor

# %%
t= DecisionTreeRegressor(max_depth=5,min_samples_leaf= 20)

# %%
t.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=20)

# %%
t.score(xtest,ytest)
# Out:
# 0.20431938775000613

# %%
# ## Classification Models
# 
# #### Model - Random forest classifier with binary class.

# #### We can group the wines into 2 classes, good and bad. For this we can consider 3,4,5,6 and bad(1) and 7,8,9 as good(2).
#

# %%
##     only for classification
df['class'] = df['quality'].map({3: 1, 4: 1,5: 1,6: 1,7: 2,8: 2,9: 2})

# %%
df = df.dropna()

# %%
x= df.loc[:,['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
             'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]

# x=df.loc[:,["volatile_acidity","citric_acid","chlorides","density","sulphates"]]
y= df.loc[:,'class']

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3, random_state=0)

# %%
ytrain
# Out:
# 2825    2.0
# 2349    1.0
# 3407    1.0
# 2526    2.0
# 4409    2.0
#        ...
# 5321    1.0
# 3511    1.0
# 1742    1.0
# 2793    1.0
# 2928    1.0
# Name: class, Length: 4237, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
r= RandomForestClassifier(max_depth=3,min_samples_leaf= 5)
r.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_leaf=5)

# %%
r.score(xtest,ytest)
# Out:
# 0.8138766519823789

# %%
# ## Model - KNN(K-Nearest Neighbors Algorithm) for Multiclass Classification.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# %%
df1 = data


# #### For Multiclass classification model we are grouping the quality variable into 3 groups. 
#quality 3,4 as bad (1) ,quality 5,6,7 as average (2) and quality 8,9 as good (3).

# %%
df1['class'] = df1['quality'].map({3: 1, 4: 1,5: 2,6: 2,7: 2,8: 3,9: 3})

# %%
test_df1 = df1.drop(['style','class'],axis=1)
test_df1.groupby(['quality']).mean()
# Out:
#          fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# quality
# 3             7.853333          0.517000     0.281000        5.140000  \
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density
# quality
# 3         0.077033            39.216667            122.033333  0.995744  \
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# 7         0.045272            30.422150            108.498610  0.993126
# 8         0.041124            34.533679            117.518135  0.992514
# 9         0.027400            33.400000            116.000000  0.991460
#
#                pH  sulphates    alcohol
# quality
# 3        3.257667   0.506333  10.215000
# 4        3.231620   0.505648  10.180093
# 5        3.212189   0.526403   9.837783
# 6        3.217726   0.532549  10.587553
# 7        3.228072   0.547025  11.386006
# 8        3.223212   0.512487  11.678756
# 9        3.308000   0.466000  12.180000

# %%
test_df1 = df1.drop(['style','quality'],axis=1)
test_df1.groupby(['class']).mean()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# class
# 1           7.357724          0.465163     0.273374        4.273984  \
# 2           7.221469          0.336151     0.319974        5.493772
# 3           6.850000          0.291187     0.333889        5.351010
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density
# class
# 1       0.062126            22.902439            105.701220  0.994944  \
# 2       0.056285            30.704940            116.095985  0.994759
# 3       0.040778            34.505051            117.479798  0.992487
#
#              pH  sulphates    alcohol
# class
# 1      3.234797   0.505732  10.184350
# 2      3.217614   0.532959  10.465055
# 3      3.225354   0.511313  11.691414

# %%
out_values=df1.iloc[:,:-3].describe(percentiles=[0.05,0.95])
out_values.drop(['count', 'mean', 'std', 'min', '50%', 'max'], axis=0, inplace=True)

# %%
for i in out_values.columns:
    check= (lambda x: x if x>=out_values.loc['5%',i] and x<=out_values.loc['95%',i] else df1[i].mean() )
    df1[i]= df1[i].apply(check)

# %%
x= df1.loc[:,['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
             'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]

# x=df.loc[:,["volatile_acidity","citric_acid","chlorides","density","sulphates"]]
y= df1.loc[:,'class']

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3, random_state=0)

# %%
knn = KNeighborsClassifier(n_neighbors = 3).fit(xtrain, ytrain)

accuracy = knn.score(xtest, ytest)
print(accuracy)
# Out:
# 0.9194871794871795

# %%
knn_predictions = knn.predict(xtest) 
confusion_m = confusion_matrix(ytest, knn_predictions)

# %%
from sklearn import metrics
print(metrics.classification_report(ytest, knn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.19      0.05      0.08        76
#            2       0.94      0.98      0.96      1817
#            3       0.28      0.14      0.19        57
#
#     accuracy                           0.92      1950
#    macro avg       0.47      0.39      0.41      1950
# weighted avg       0.89      0.92      0.90      1950

# %%
# ## Insights: 
# 
# #### The KNN model is giving better accuracy and the precision and recall values for each class are 
#also good we can use this
#model as a simulator if the wine maker wants to check the quality of wine by changing few parameter.
